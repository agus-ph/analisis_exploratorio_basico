# %% [markdown]
# # Análisis Exploratorio con Python Pandas

# %% [markdown]
# ### Importar librerías

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Cargamos el dataset a explorar como DataFrame de Pandas. Si el dataset ya tiene una columna que pueda servir como indice ya la podemos asignar en lugar de la columna id que Pandas agrega automaticamente

# %%
df = pd.read_csv("shoes_dataset.csv", index_col="InvoiceNo")

# %% [markdown]
# ### Para ir conociendo el dataset podemos utilizar las funciones de Pandas que nos permiten ver su tamaño, forma, columnas, y el tipo de datos de cada columna

# %%
print("Tamaño= ", df.size)
print("Forma= ", df.shape)
print("columnas= ", df.columns)
print("Tipos de dato=\n",df.dtypes)
# Out:
# Tamaño=  164637
# Forma=  (14967, 11)
# columnas=  Index(['Date', 'Country', 'ProductID', 'Shop', 'Gender', 'Size (US)',
#        'Size (Europe)', 'Size (UK)', 'UnitPrice', 'Discount', 'SalePrice'],
#       dtype='object')
# Tipos de dato=
#  Date              object
# Country           object
# ProductID          int64
# Shop              object
# Gender            object
# Size (US)        float64
# Size (Europe)     object
# Size (UK)        float64
# UnitPrice         object
# Discount          object
# SalePrice         object
# dtype: object

# %% [markdown]
# ### Otra forma de ver algo similar a lo que vimos arriba pero que tambien nos muetsra el uso de memoria y la cantidad de campos nulos por columna es la función .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14967 entries, 52389 to 65777
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           14967 non-null  object
#  1   Country        14967 non-null  object
#  2   ProductID      14967 non-null  int64
#  3   Shop           14967 non-null  object
#  4   Gender         14967 non-null  object
#  5   Size (US)      14967 non-null  float64
#  6   Size (Europe)  14967 non-null  object
#  7   Size (UK)      14967 non-null  float64
#  8   UnitPrice      14967 non-null  object
#  9   Discount       14967 non-null  object
#  10  SalePrice      14967 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Con la función .head() podemos ver las primeras 5 filas del dataset (o mas si pasamos el número de filas que queremos ver como parámetro)

# %%
df.head()
# Out:
#                Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52389      1/1/2014  United Kingdom       2152   UK2    Male         11
# 52390      1/1/2014   United States       2230  US15    Male         12
# 52391      1/1/2014          Canada       2160  CAN7    Male         10
# 52392      1/1/2014   United States       2234   US6  Female         10
# 52393      1/1/2014  United Kingdom       2222   UK4  Female          9
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52389                44         10   $159.00        0%   $159.00
# 52390             44-45         11   $199.00       20%   $159.20
# 52391             42-43          9   $149.00       20%   $119.20
# 52392                40          8   $159.00        0%   $159.00
# 52393             39-40          7   $159.00        0%   $159.00

# %% [markdown]
# ### Podemos tener una descripción estadística rápida utilizando la función .descrive(). Está función solo servirá para las columnas que tengan datos numéricos

# %%
df.describe()
# Out:
#        ProductID  Size (US)  Size (UK)
# count     14,967     14,967     14,967
# mean       2,195          9          8
# std           28          2          2
# min        2,147          4          2
# 25%        2,172          8          6
# 50%        2,195          9          8
# 75%        2,219         10         10
# max        2,242         15         14

# %% [markdown]
# ## Filtrado de filas y columnas. Funciones .loc e .iloc

# %% [markdown]
# ## Función .loc

# %% [markdown]
# ### Con la función .loc podemos filtrar utilizando el número de id y/o el nombre de la columna

# %%
# Por un número de id específico
df.loc[[52392]]
# Out:
#                Date        Country  ProductID Shop  Gender  Size (US)  \
# InvoiceNo
# 52392      1/1/2014  United States       2234  US6  Female         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52392                40          8   $159.00        0%   $159.00

# %%
# Por un rángo de números de id
df.loc[52389:52393]
# Out:
#                Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52389      1/1/2014  United Kingdom       2152   UK2    Male         11
# 52390      1/1/2014   United States       2230  US15    Male         12
# 52391      1/1/2014          Canada       2160  CAN7    Male         10
# 52392      1/1/2014   United States       2234   US6  Female         10
# 52393      1/1/2014  United Kingdom       2222   UK4  Female          9
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52389                44         10   $159.00        0%   $159.00
# 52390             44-45         11   $199.00       20%   $159.20
# 52391             42-43          9   $149.00       20%   $119.20
# 52392                40          8   $159.00        0%   $159.00
# 52393             39-40          7   $159.00        0%   $159.00

# %%
# Por un nombre de columna especifico (observar que como primer parámetro pasamos el rango completo de filas)
df.loc[:, ["UnitPrice"]]
# Out:
#            UnitPrice
# InvoiceNo
# 52389       $159.00
# 52390       $199.00
# 52391       $149.00
# 52392       $159.00
# 52393       $159.00
# ...              ...
# 65773       $139.00
# 65774       $149.00
# 65775       $179.00
# 65776       $199.00
# 65777       $139.00
#
# [14967 rows x 1 columns]

# %%
# Especificando los id mas las columna que nos interesan
# Ejemplo 1
df.loc[52389:52392, ["Gender","Size (Europe)", "UnitPrice"]]
# Out:
#            Gender Size (Europe)  UnitPrice
# InvoiceNo
# 52389        Male            44   $159.00
# 52390        Male         44-45   $199.00
# 52391        Male         42-43   $149.00
# 52392      Female            40   $159.00

# %%
# Ejemplo 2
df.loc[[52389, 52391] , ["Size (Europe)", "UnitPrice"]]
# Out:
#           Size (Europe)  UnitPrice
# InvoiceNo
# 52389                44   $159.00
# 52391             42-43   $149.00

# %% [markdown]
# ## Función .iloc

# %% [markdown]
# ### Con la función .iloc pódemos hacer algo similar pero moviendonos por los números de indice que asigna pandas (no confundir con id)

# %%
# Elegimos un número concreto de fila
df.iloc[[5]]
# Out:
#                Date        Country  ProductID  Shop Gender  Size (US)  \
# InvoiceNo
# 52394      1/1/2014  United States       2173  US15   Male         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52394             43-44         10   $159.00        0%   $159.00

# %%
# Elegimos un rango de filas
df.iloc[2:5]
# Out:
#                Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52391      1/1/2014          Canada       2160  CAN7    Male         10
# 52392      1/1/2014   United States       2234   US6  Female         10
# 52393      1/1/2014  United Kingdom       2222   UK4  Female          9
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52392                40          8   $159.00        0%   $159.00
# 52393             39-40          7   $159.00        0%   $159.00

# %%
# Una lista de filas
df.iloc[[1,5,8,25]]
# Out:
#                Date        Country  ProductID  Shop Gender  Size (US)  \
# InvoiceNo
# 52390      1/1/2014  United States       2230  US15   Male         12
# 52394      1/1/2014  United States       2173  US15   Male         10
# 52397      1/2/2014  United States       2191  US13   Male         10
# 52409      1/4/2014        Germany       2157  GER2   Male         12
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52390             44-45         11   $199.00       20%   $159.20
# 52394             43-44         10   $159.00        0%   $159.00
# 52397             43-44         10   $139.00        0%   $139.00
# 52409                45         12   $149.00       20%   $119.20

# %%
# Columnas por indice (observar que como primer parámetro pasamos el rango completo de filas)
df.iloc[: , 0:3]
# Out:
#                  Date         Country  ProductID
# InvoiceNo
# 52389        1/1/2014  United Kingdom       2152
# 52390        1/1/2014   United States       2230
# 52391        1/1/2014          Canada       2160
# 52392        1/1/2014   United States       2234
# 52393        1/1/2014  United Kingdom       2222
# ...               ...             ...        ...
# 65773      12/31/2016  United Kingdom       2154
# 65774      12/31/2016   United States       2181
# 65775      12/31/2016          Canada       2203
# 65776      12/31/2016         Germany       2231
# 65777      12/31/2016         Germany       2156
#
# [14967 rows x 3 columns]

# %%
# Una lista de columnas (observar que como primer parámetro pasamos el rango completo de filas)
df.iloc[: , [1,3,5]]
# Out:
#                   Country  Shop  Size (US)
# InvoiceNo
# 52389      United Kingdom   UK2         11
# 52390       United States  US15         12
# 52391              Canada  CAN7         10
# 52392       United States   US6         10
# 52393      United Kingdom   UK4          9
# ...                   ...   ...        ...
# 65773      United Kingdom   UK2         10
# 65774       United States  US12         12
# 65775              Canada  CAN6         10
# 65776             Germany  GER1         10
# 65777             Germany  GER1          6
#
# [14967 rows x 3 columns]

# %%
# Filas y columnas por rango
df.iloc[2:6 , 1:4]
# Out:
#                   Country  ProductID  Shop
# InvoiceNo
# 52391              Canada       2160  CAN7
# 52392       United States       2234   US6
# 52393      United Kingdom       2222   UK4
# 52394       United States       2173  US15

# %%
# Listas de indiceas de filas y columnas 
df.iloc[[2,5,35] , [2,5,8]]
# Out:
#            ProductID  Size (US)  UnitPrice
# InvoiceNo
# 52391           2160         10   $149.00
# 52394           2173         10   $159.00
# 52416           2235         10   $169.00

# %% [markdown]
# ## Filtrado condicional

# %% [markdown]
# ### Filtrando por condicones númericas

# %%
# FIltrando por una sola columna numerica
df[df["Size (US)"] > 9.0]
# Out:
#                  Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52389        1/1/2014  United Kingdom       2152   UK2    Male         11
# 52390        1/1/2014   United States       2230  US15    Male         12
# 52391        1/1/2014          Canada       2160  CAN7    Male         10
# 52392        1/1/2014   United States       2234   US6  Female         10
# 52394        1/1/2014   United States       2173  US15    Male         10
# ...               ...             ...        ...   ...     ...        ...
# 65769      12/31/2016         Germany       2210  GER2    Male         10
# 65773      12/31/2016  United Kingdom       2154   UK2    Male         10
# 65774      12/31/2016   United States       2181  US12  Female         12
# 65775      12/31/2016          Canada       2203  CAN6    Male         10
# 65776      12/31/2016         Germany       2231  GER1  Female         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52389                44         10   $159.00        0%   $159.00
# 52390             44-45         11   $199.00       20%   $159.20
# 52391             42-43          9   $149.00       20%   $119.20
# 52392                40          8   $159.00        0%   $159.00
# 52394             43-44         10   $159.00        0%   $159.00
# ...                 ...        ...        ...      ...        ...
# 65769             43-44         10   $179.00       50%    $89.50
# 65773             42-43          9   $139.00        0%   $139.00
# 65774             42-43         10   $149.00        0%   $149.00
# 65775             43-44         10   $179.00       30%   $125.30
# 65776                40          8   $199.00        0%   $199.00
#
# [7128 rows x 11 columns]

# %%
# Poniendo mas de una condición numérica
df[(df["Size (US)"] > 9.0) & (df["Size (UK)"] < 10.5)]
# Out:
#                  Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52391        1/1/2014          Canada       2160  CAN7    Male         10
# 52392        1/1/2014   United States       2234   US6  Female         10
# 52394        1/1/2014   United States       2173  US15    Male         10
# 52396        1/2/2014          Canada       2238  CAN5    Male         10
# 52397        1/2/2014   United States       2191  US13    Male         10
# ...               ...             ...        ...   ...     ...        ...
# 65769      12/31/2016         Germany       2210  GER2    Male         10
# 65773      12/31/2016  United Kingdom       2154   UK2    Male         10
# 65774      12/31/2016   United States       2181  US12  Female         12
# 65775      12/31/2016          Canada       2203  CAN6    Male         10
# 65776      12/31/2016         Germany       2231  GER1  Female         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52392                40          8   $159.00        0%   $159.00
# 52394             43-44         10   $159.00        0%   $159.00
# 52396                43         10   $169.00        0%   $169.00
# 52397             43-44         10   $139.00        0%   $139.00
# ...                 ...        ...        ...      ...        ...
# 65769             43-44         10   $179.00       50%    $89.50
# 65773             42-43          9   $139.00        0%   $139.00
# 65774             42-43         10   $149.00        0%   $149.00
# 65775             43-44         10   $179.00       30%   $125.30
# 65776                40          8   $199.00        0%   $199.00
#
# [5613 rows x 11 columns]

# %% [markdown]
# ### Filtrado por cadena de texto

# %%
# Con una sola condición
df[df["Country"].str.contains("Canada")]
# Out:
#                  Date Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52391        1/1/2014  Canada       2160  CAN7    Male         10
# 52396        1/2/2014  Canada       2238  CAN5    Male         10
# 52402        1/3/2014  Canada       2240  CAN6    Male         10
# 52410        1/4/2014  Canada       2169  CAN3  Female          8
# 52415        1/5/2014  Canada       2169  CAN3  Female          8
# ...               ...     ...        ...   ...     ...        ...
# 65747      12/29/2016  Canada       2217  CAN7    Male          9
# 65749      12/30/2016  Canada       2206  CAN6    Male          9
# 65763      12/30/2016  Canada       2161  CAN5    Male          8
# 65765      12/31/2016  Canada       2199  CAN5    Male         11
# 65775      12/31/2016  Canada       2203  CAN6    Male         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52396                43         10   $169.00        0%   $169.00
# 52402             42-43          9   $199.00       30%   $139.30
# 52410             38-39          6   $129.00        0%   $129.00
# 52415             38-39          6   $129.00        0%   $129.00
# ...                 ...        ...        ...      ...        ...
# 65747                42          8   $199.00        0%   $199.00
# 65749                42          8   $169.00       20%   $135.20
# 65763                41          8   $129.00        0%   $129.00
# 65765                44         10   $139.00        0%   $139.00
# 65775             43-44         10   $179.00       30%   $125.30
#
# [2952 rows x 11 columns]

# %%
# Con mas de una condición
# Ejemplo 1
df[(df["Country"].str.contains("Canada")) & (df["Size (Europe)"].str.contains("42-43"))]
# Out:
#                  Date Country  ProductID  Shop Gender  Size (US)  \
# InvoiceNo
# 52391        1/1/2014  Canada       2160  CAN7   Male         10
# 52402        1/3/2014  Canada       2240  CAN6   Male         10
# 52425        1/7/2014  Canada       2160  CAN7   Male         10
# 52439        1/9/2014  Canada       2160  CAN7   Male         10
# 52470       1/15/2014  Canada       2178  CAN5   Male         10
# ...               ...     ...        ...   ...    ...        ...
# 65709      12/26/2016  Canada       2213  CAN5   Male         10
# 65721      12/27/2016  Canada       2240  CAN6   Male         10
# 65731      12/28/2016  Canada       2198  CAN6   Male         10
# 65731      12/28/2016  Canada       2171  CAN3   Male         10
# 65745      12/29/2016  Canada       2171  CAN3   Male         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52402             42-43          9   $199.00       30%   $139.30
# 52425             42-43          9   $149.00       20%   $119.20
# 52439             42-43          9   $149.00       20%   $119.20
# 52470             42-43          9   $139.00       10%   $125.10
# ...                 ...        ...        ...      ...        ...
# 65709             42-43          9   $129.00       50%    $64.50
# 65721             42-43          9   $199.00       30%   $139.30
# 65731             42-43          9   $179.00       10%   $161.10
# 65731             42-43          9   $139.00        0%   $139.00
# 65745             42-43          9   $139.00        0%   $139.00
#
# [396 rows x 11 columns]

# %%
# Ejemplo 2
df[(df["Country"].str.contains("Canada")) | (df["Size (Europe)"].str.contains("42-43"))]
# Out:
#                  Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52391        1/1/2014          Canada       2160  CAN7    Male         10
# 52396        1/2/2014          Canada       2238  CAN5    Male         10
# 52402        1/3/2014          Canada       2240  CAN6    Male         10
# 52406        1/3/2014   United States       2147  US15    Male         10
# 52410        1/4/2014          Canada       2169  CAN3  Female          8
# ...               ...             ...        ...   ...     ...        ...
# 65766      12/31/2016  United Kingdom       2202   UK1    Male         10
# 65767      12/31/2016   United States       2147  US15    Male         10
# 65773      12/31/2016  United Kingdom       2154   UK2    Male         10
# 65774      12/31/2016   United States       2181  US12  Female         12
# 65775      12/31/2016          Canada       2203  CAN6    Male         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52396                43         10   $169.00        0%   $169.00
# 52402             42-43          9   $199.00       30%   $139.30
# 52406             42-43          9   $139.00        0%   $139.00
# 52410             38-39          6   $129.00        0%   $129.00
# ...                 ...        ...        ...      ...        ...
# 65766             42-43          9   $159.00       30%   $111.30
# 65767             42-43          9   $139.00        0%   $139.00
# 65773             42-43          9   $139.00        0%   $139.00
# 65774             42-43         10   $149.00        0%   $149.00
# 65775             43-44         10   $179.00       30%   $125.30
#
# [4524 rows x 11 columns]

# %%
# Otro ejemplo utilizando mas de una condición por columna
df[(df["Country"].str.contains("Canada", "United Kingdom")) & (df["Size (Europe)"].str.contains("42-43", "43-44"))]
# Out:
#                  Date Country  ProductID  Shop Gender  Size (US)  \
# InvoiceNo
# 52391        1/1/2014  Canada       2160  CAN7   Male         10
# 52402        1/3/2014  Canada       2240  CAN6   Male         10
# 52425        1/7/2014  Canada       2160  CAN7   Male         10
# 52439        1/9/2014  Canada       2160  CAN7   Male         10
# 52470       1/15/2014  Canada       2178  CAN5   Male         10
# ...               ...     ...        ...   ...    ...        ...
# 65709      12/26/2016  Canada       2213  CAN5   Male         10
# 65721      12/27/2016  Canada       2240  CAN6   Male         10
# 65731      12/28/2016  Canada       2198  CAN6   Male         10
# 65731      12/28/2016  Canada       2171  CAN3   Male         10
# 65745      12/29/2016  Canada       2171  CAN3   Male         10
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice
# InvoiceNo
# 52391             42-43          9   $149.00       20%   $119.20
# 52402             42-43          9   $199.00       30%   $139.30
# 52425             42-43          9   $149.00       20%   $119.20
# 52439             42-43          9   $149.00       20%   $119.20
# 52470             42-43          9   $139.00       10%   $125.10
# ...                 ...        ...        ...      ...        ...
# 65709             42-43          9   $129.00       50%    $64.50
# 65721             42-43          9   $199.00       30%   $139.30
# 65731             42-43          9   $179.00       10%   $161.10
# 65731             42-43          9   $139.00        0%   $139.00
# 65745             42-43          9   $139.00        0%   $139.00
#
# [396 rows x 11 columns]

# %% [markdown]
# ## Agragar columnas al datagrame

# %% [markdown]
# ### Algunas veces necesitamos agregar datos a partir de los que ya tenemos. Como ejemplo en nuestro caso voy a agregar una columna donde nos muestre el continente al que pertenece la tienda utilizandola columna "Country"

# %%
# Primero identifico los valores únicos de la columna Countrt
df["Country"].unique()
# Out:
# array(['United Kingdom', 'United States', 'Canada', 'Germany'],
#       dtype=object)

# %%
# Segundo creo una función que identifique el continente al que pertenece cada país
def continents(Country):
    for continent in Country:
        if Country == "United Kingdom" or Country == "Germany":
            continent = "Europe"
        else:
            continent = "America"
        return continent

# %%
# Creamos la nueva columna aplicando la función y vemos como queda el dataframe
df["Continent"] = df["Country"].apply(continents)
df.head()
# Out:
#                Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52389      1/1/2014  United Kingdom       2152   UK2    Male         11
# 52390      1/1/2014   United States       2230  US15    Male         12
# 52391      1/1/2014          Canada       2160  CAN7    Male         10
# 52392      1/1/2014   United States       2234   US6  Female         10
# 52393      1/1/2014  United Kingdom       2222   UK4  Female          9
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice Continent
# InvoiceNo
# 52389                44         10   $159.00        0%   $159.00     Europe
# 52390             44-45         11   $199.00       20%   $159.20    America
# 52391             42-43          9   $149.00       20%   $119.20    America
# 52392                40          8   $159.00        0%   $159.00    America
# 52393             39-40          7   $159.00        0%   $159.00     Europe

# %% [markdown]
# ## Cambiar el tipo de dato de una columna

# %% [markdown]
# ### En este caso queremos cambiar el tipo de dato de las columnas "UnitPrice" y "SalePrice" de object a float64 para poder realizar operaciones

# %%
df["UnitPrice"] = df["UnitPrice"].str.replace("[\$]", "", regex=True).astype(float)
df["SalePrice"] = df["SalePrice"].str.replace("[\$]", "", regex=True).astype(float)

# %%
# Con la función .dtypes vemos que cambiaron de object a float64
df.dtypes
# Out:
# Date              object
# Country           object
# ProductID          int64
# Shop              object
# Gender            object
# Size (US)        float64
# Size (Europe)     object
# Size (UK)        float64
# UnitPrice        float64
# Discount          object
# SalePrice        float64
# Continent         object
# dtype: object

# %%
# Vemos como queda el dataframe
df.head()
# Out:
#                Date         Country  ProductID  Shop  Gender  Size (US)  \
# InvoiceNo
# 52389      1/1/2014  United Kingdom       2152   UK2    Male         11
# 52390      1/1/2014   United States       2230  US15    Male         12
# 52391      1/1/2014          Canada       2160  CAN7    Male         10
# 52392      1/1/2014   United States       2234   US6  Female         10
# 52393      1/1/2014  United Kingdom       2222   UK4  Female          9
#
#           Size (Europe)  Size (UK)  UnitPrice Discount  SalePrice Continent
# InvoiceNo
# 52389                44         10        159       0%        159    Europe
# 52390             44-45         11        199      20%        159   America
# 52391             42-43          9        149      20%        119   America
# 52392                40          8        159       0%        159   America
# 52393             39-40          7        159       0%        159    Europe

# %%
# Provmos la funcion .describe para ver si ahora nos toma el precio unitario y de venta
df.describe()
# Out:
#        ProductID  Size (US)  Size (UK)  UnitPrice  SalePrice
# count     14,967     14,967     14,967     14,967     14,967
# mean       2,195          9          8        164        144
# std           28          2          2         23         35
# min        2,147          4          2        129         64
# 25%        2,172          8          6        149        125
# 50%        2,195          9          8        159        149
# 75%        2,219         10         10        179        169
# max        2,242         15         14        199        199
